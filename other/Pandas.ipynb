# %%
import pandas as pd 

df = pd.read_csv('./data/vehicles/vehicles.csv')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df[(df["Year"] == 2014) & (df["Year"] == 2015)]["Year"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-0c03e36af6c8> in <module>
# ----> 1 df[(df["Year"] == 2014) or (df["Year"] == 2015)]["Year"]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477         raise ValueError("The truth value of a {0} is ambiguous. "
#    1478                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1479                          .format(self.__class__.__name__))
#    1480
#    1481     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
a = 6
b = 10

if a > 5 and b < 12:
    print("Hola")
# Out:
# Hola

# %%
x = df[(df["Year"] == 2014) & (df["Make"] == "Ford")].transpose()
x.head()
# Out:
#                                            11640             11644  \
# Make                                        Ford              Ford
# Model                C-MAX Energi Plug-in Hybrid  C-MAX Hybrid FWD
# Year                                        2014              2014
# Engine Displacement                            2                 2
# Cylinders                                      4                 4
#
#                             11915         11916           11923  \
# Make                         Ford          Ford            Ford
# Model                E150 Van FFV  E150 Van FFV  E150 Wagon FFV
# Year                         2014          2014            2014
# Engine Displacement           5.4           4.6             5.4
# Cylinders                       8             8               8
#
#                               11924         12004         12005     12009  \
# Make                           Ford          Ford          Ford      Ford
# ...

# %%
x.loc[["Make"]]
# Out:
#      11640 11644 11915 11916 11923 11924 12004 12005 12009 12013  ... 14118  \
# Make  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford  ...  Ford
#
#      14124 14139 14140 14146 14324 14325 14337 14338 14346
# Make  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford
#
# [1 rows x 86 columns]

# %%
# The same
display(x.iloc[0])
display(x.iloc[0,:])
# Out:
# 11640    Ford
# 11644    Ford
# 11915    Ford
# 11916    Ford
# 11923    Ford
# 11924    Ford
# 12004    Ford
# 12005    Ford
# 12009    Ford
# 12013    Ford
# 12017    Ford
# 12021    Ford
# 12046    Ford
# 12047    Ford
# 12067    Ford
# 12068    Ford
# 12069    Ford
# 12115    Ford
# 12116    Ford
# 12145    Ford
# 12146    Ford
# 12147    Ford
# 12338    Ford
# 12364    Ford
# 12425    Ford
# 12487    Ford
# 12488    Ford
# 12498    Ford
# 12508    Ford
# 12509    Ford
#          ...
# 13304    Ford
# 13321    Ford
# 13322    Ford
# 13323    Ford
# 13335    Ford
# 13400    Ford
# 13409    Ford
# 13432    Ford
# 13433    Ford
# 13434    Ford
# 13435    Ford
# 13436    Ford
# 13455    Ford
# 13661    Ford
# 13662    Ford
# 13663    Ford
# 13664    Ford
# 13665    Ford
# 13687    Ford
# 14117    Ford
# 14118    Ford
# 14124    Ford
# 14139    Ford
# 14140    Ford
# 14146    Ford
# 14324    Ford
# 14325    Ford
# 14337    Ford
# 14338    Ford
# 14346    Ford
# ...

# %%
display(x.iloc[:,0])
# Out:
# Make                                                   Ford
# Model                           C-MAX Energi Plug-in Hybrid
# Year                                                   2014
# Engine Displacement                                       2
# Cylinders                                                 4
# Transmission               Automatic (variable gear ratios)
# Drivetrain                                Front-Wheel Drive
# Vehicle Class                                  Midsize Cars
# Fuel Type                       Regular Gas and Electricity
# Fuel Barrels/Year                                    4.8787
# City MPG                                                 40
# Highway MPG                                              36
# Combined MPG                                             38
# CO2 Emission Grams/Mile                                 129
# Fuel Cost/Year                                          900
# Name: 11640, dtype: object

# %%
display(x.iloc[[0]])
# Out:
#      11640 11644 11915 11916 11923 11924 12004 12005 12009 12013  ... 14118  \
# Make  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford  ...  Ford
#
#      14124 14139 14140 14146 14324 14325 14337 14338 14346
# Make  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford  Ford
#
# [1 rows x 86 columns]

# %%
display(df.loc[11640])
# Out:
# Make                                                   Ford
# Model                           C-MAX Energi Plug-in Hybrid
# Year                                                   2014
# Engine Displacement                                       2
# Cylinders                                                 4
# Transmission               Automatic (variable gear ratios)
# Drivetrain                                Front-Wheel Drive
# Vehicle Class                                  Midsize Cars
# Fuel Type                       Regular Gas and Electricity
# Fuel Barrels/Year                                    4.8787
# City MPG                                                 40
# Highway MPG                                              36
# Combined MPG                                             38
# CO2 Emission Grams/Mile                                 129
# Fuel Cost/Year                                          900
# Name: 11640, dtype: object

# %%
x.reset_index(drop=True)
# Out:
#                                11640                             11644  \
# 0                               Ford                              Ford
# 1        C-MAX Energi Plug-in Hybrid                  C-MAX Hybrid FWD
# 2                               2014                              2014
# 3                                  2                                 2
# 4                                  4                                 4
# 5   Automatic (variable gear ratios)  Automatic (variable gear ratios)
# 6                  Front-Wheel Drive                 Front-Wheel Drive
# 7                       Midsize Cars                        Large Cars
# 8        Regular Gas and Electricity                           Regular
# 9                             4.8787                           8.24025
# 10                                40                                42
# 11                                36                                37
# ...

# %%
# %matplotlib inline
df[df["Make"]=="Audi"].groupby(["Year"]).mean()["Combined MPG"].plot()

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html?highlight=apply#pandas.DataFrame.apply
def changefn(row):
    make = row[0]
    model = row[1]
    return "Vaya pedazo de {} {} que te has comprado".format(make,model)
    
m = df.head()[["Make","Model"]]
sr = m.apply(changefn, axis=1)
m["texto"] = sr
m
# Out:
#                Make                Model  \
# 0        AM General    DJ Po Vehicle 2WD
# 1        AM General     FJ8c Post Office
# 2        AM General  Post Office DJ5 2WD
# 3        AM General  Post Office DJ8 2WD
# 4  ASC Incorporated                  GNX
#
#                                                texto
# 0  Vaya pedazo de AM General DJ Po Vehicle 2WD qu...
# 1  Vaya pedazo de AM General FJ8c Post Office que...
# 2  Vaya pedazo de AM General Post Office DJ5 2WD ...
# 3  Vaya pedazo de AM General Post Office DJ8 2WD ...
# 4  Vaya pedazo de ASC Incorporated GNX que te has...

# %%
def changefn(row):
    make = row[0]
    model = row[1]
    return ("Marca: "+make,"Modelo: "+model)
    
m = df.head()[["Make","Model"]]
a = m.apply(changefn, axis=1, broadcast=True)
display(a)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: The broadcast argument is deprecated and will be removed in a future version. You can specify result_type='broadcast' to broadcast the result to the original dimensions
#   import sys
#                       Make                        Model
# 0        Marca: AM General    Modelo: DJ Po Vehicle 2WD
# 1        Marca: AM General     Modelo: FJ8c Post Office
# 2        Marca: AM General  Modelo: Post Office DJ5 2WD
# 3        Marca: AM General  Modelo: Post Office DJ8 2WD
# 4  Marca: ASC Incorporated                  Modelo: GNX

# %%
b = df.head()[["Year","Combined MPG"]]
b
# Out:
#    Year  Combined MPG
# 0  1984            17
# 1  1984            13
# 2  1985            16
# 3  1985            13
# 4  1987            16

# %%
pd.concat([a,b], axis=1)
# Out:
#                       Make                        Model  Year  Combined MPG
# 0        Marca: AM General    Modelo: DJ Po Vehicle 2WD  1984            17
# 1        Marca: AM General     Modelo: FJ8c Post Office  1984            13
# 2        Marca: AM General  Modelo: Post Office DJ5 2WD  1985            16
# 3        Marca: AM General  Modelo: Post Office DJ8 2WD  1985            13
# 4  Marca: ASC Incorporated                  Modelo: GNX  1987            16

# %%
q = [1,2,3]
p = [4,5,6]
print(list(zip(q,p)))
list(enumerate(zip(q,p)))
# Out:
# [(1, 4), (2, 5), (3, 6)]
# [(0, (1, 4)), (1, (2, 5)), (2, (3, 6))]

# %%
for i,e in enumerate(zip(q,p)):
    a,b = e
    print("El elemento {} contiene {},{}".format(i,a,b))
# Out:
# El elemento 0 contiene 1,4
# El elemento 1 contiene 2,5
# El elemento 2 contiene 3,6
